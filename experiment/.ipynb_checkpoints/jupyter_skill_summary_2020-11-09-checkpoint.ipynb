# %%
import tensorflow as tf

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.mnist.load_data()

# %%
train_x.shape, test_x.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# jupyter notebook 使用的技巧参考下面的链接
# https://developer.aliyun.com/article/84793
#
#
# Esc + F 在代码中查找、替换，忽略输出。
#
# Esc + O 在cell和输出结果间切换。
#
# 选择多个cell:
#
# Shift + J 或 Shift + Down 选择下一个cell。
#
# Shift + K 或 Shift + Up 选择上一个cell。
#
# 一旦选定cell，可以批量删除/拷贝/剪切/粘贴/运行。当你需要移动notebook的一部分时这个很有用。
#
# Shift + M 合并cell.

# %%
import tensorflow as tf

(train_x, train_y), (test_x, test_y) = tf.keras.datasets.mnist.load_data()

train_x.shape, test_x.shape

# %%
# 在库、方法或变量的前面打上?，即可打开相关语法的帮助文档。
# ?tf.keras.datasets.mnist.load_data

# %%
# matplotlib （事实标准）（http://matplotlib.org/），可通过%matplotlib inline 激活，（https://www.dataquest.io/blog/matplotlib-tutorial/） 
# %matplotlib inline

# %%
# 使用%run 可以直接在jupyter里面运行其他的ipynb
# %run boston_housing-2020-11-08.ipynb
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 64)                896
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# ...
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 404/404 [==============================] - 1s 1ms/step - loss: 0.3899 - accuracy: 0.0000e+00 - val_loss: 0.3003 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 404/404 [==============================] - 0s 1ms/step - loss: 0.1767 - accuracy: 0.0000e+00 - val_loss: 0.2711 - val_accuracy: 0.0000e+00
# Epoch 3/100
# ...

# %%
# %run 也可以执行py文件，他只是运行，不能作为调用或者导入包使用
# %run experiment.py
# Out:
# init modole ...
# set Optimizer
# caculation begins ...
# caculation ends ...
# ##After Caculation:
#    B: 0.999988, W : 2.000018
# quit

# %%
# 使用%load 可以把外部的py文件直接导入到本jupyter里面
# %load experiment.py
import tensorflow.compat.v1 as tf
import numpy      as np
import os
import matplotlib.pyplot as plt

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

xdata = np.linspace(0,1,100)
ydata = 2 * xdata + 1

tf.disable_eager_execution()

print("init modole ...")
X = tf.placeholder("float",name="X")
Y = tf.placeholder("float",name="Y")
W = tf.Variable(3., name="W")
B = tf.Variable(3., name="B")
# 这个是明显的define and run，先定义后运行
linearmodel = tf.add(tf.multiply(X,W),B)
lossfunc = (tf.pow(Y - linearmodel, 2))
learningrate = 0.01

print("set Optimizer")
trainoperation = tf.train.GradientDescentOptimizer(learningrate).minimize(lossfunc)

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

print("caculation begins ...")
for j in range(100):
  for i in range(100):
#     run的时候才正式运算，先把placeholder位置赋予值（给X,Y赋值）
    sess.run(trainoperation, feed_dict={X: xdata[i], Y:ydata[i]})
    #print("i = " + str(i) + "b: " + str(B.eval(session=sess)) + ", w : " + str(W.eval(session=sess)))
print("caculation ends ...")
print("##After Caculation: ") 
print("   B: " + str(B.eval(session=sess)) + ", W : " + str(W.eval(session=sess)))

plt.scatter(xdata,ydata)
plt.plot(xdata,ydata,'r',label='expected: 3*x + 1')
plt.plot(xdata,B.eval(session=sess)+W.eval(session=sess)*xdata,'b',label='caculated : w*x + b')
plt.legend()
plt.show()
print("quit")
# Out:
# init modole ...
# set Optimizer
# caculation begins ...
# caculation ends ...
# ##After Caculation:
#    B: 0.999988, W : 2.000018
# quit

# %%
# 不加任何参数， %who 命令可以列出所有的全局变量。加上参数 str 将只列出字符串型的全局变量。
# %who
# Out:
# B	 Dense	 Sequential	 W	 X	 X_test	 X_train	 X_train_mean	 X_train_std
# Y	 boston_housing	 i	 init	 j	 json	 learningrate	 linearmodel	 lossfunc
# model	 np	 os	 plt	 sess	 tensorflow	 test_x	 test_y	 tf
# train_x	 train_y	 trainoperation	 xdata	 y_test	 y_train	 y_train_mean	 y_train_std	 yapf_reformat
# ydata

# %%
str_var="1111"
# %who str
# Out:
# str	 str_var

# %%
# %time 会告诉你cell内代码的单次运行时间信息。
# %time
import time
for _ in range(1000):
    time.sleep(0.01)# sleep for 0.01 seconds
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
# 使用%prun+函数声明会给你一个按顺序排列的表格，显示每个内部函数的耗时情况，每次调用函数的耗时情况，以及累计耗时。
# %prun  tf.keras.datasets.mnist.load_data()

# %% [markdown]
# Jupyter 有自己的调试界面The Python Debugger (pdb)（https://docs.python.org/3.5/library/pdb.html），使得进入函数内部检查错误成为可能。
#
#
# Pdb中可使用的命令见链接（https://docs.python.org/3.5/library/pdb.html#debugger-commands）
#
# https://developer.aliyun.com/article/84793

# %%
# 有时候不让末句的函数输出结果比较方便，比如在作图的时候，此时，只需在该函数末尾加上一个分号即可。
abc="abc"
print("ddd")
abc;
# Out:
# ddd

# %%
# 当你在一个Markdown单元格里写LaTex时，它将用MathJax呈现公式

# %% [markdown]
# Damian Avila的RISE（https://github.com/damianavila/RISE）允许你从已有的notebook创建一个powerpoint形式的演示稿。
#
# 你可以用conda来安装RISE：
#
# conda install -c damianavila82 rise
#
# 或者用pip安装：
#
# pip install RISE
#
# 然后运行下面的代码来安装和激活延伸程序：
#
# jupyter-nbextension install rise --py --sys-prefix
# jupyter-nbextension enable rise --py --sys-prefix

# %%
# !jupyter-nbextension enable rise --py --sys-prefix
# Out:
# Enabling notebook extension rise/main...
#       - Validating: OK

# %%
import os
from IPython.display import display, Image

# 下面这种方法非常不错，快速的查找一个目录下面所有的指定格式的文件，并返回结果
names = [
    f for f in os.listdir('../picture/') if f.endswith('.jpg')
]
for name in names[:5]:
    display(Image('../picture/' + name, width=100))
